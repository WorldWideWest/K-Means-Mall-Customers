# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('./source/datasets_177976_401124_Mall_Customers.csv')
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
lower = 15
upper = 35

filtered = data[
    (data.Age >= lower) & (data.Age <= upper)
]

# %%
filtered
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 192         193    Male   33                 113                       8
# 195         196  Female   35                 120                      79
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [98 rows x 5 columns]

# %%
# maping genders 1-Female, 0-Male
data['Genre'] = data['Genre'].map({'Female': 1, 'Male': 0}) 
data.head()
# Out:
#    CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1      0   19                  15                      39
# 1           2      0   21                  15                      81
# 2           3      1   20                  16                       6
# 3           4      1   23                  16                      77
# 4           5      1   31                  17                      40

# %%
dataF = data[data['Genre'] == 1].count()
dataM = data[data['Genre'] == 0].count()
genderData = pd.DataFrame({'Gender': ['Female', 'Male'],
                           'count': [dataF[0], dataM[0]]})

plt.bar(x = genderData['Gender'],
        height = genderData['count'],
        color = ['#D74E09', '#6E0E0A'],
        width = 0.4,
        align = 'center')

plt.title('Number of participants in the survey, devided into Genders',
          fontsize = 14,
          fontweight = 'bold')
plt.xlabel('Gender',
          fontsize = 12,
          fontweight = 'bold')
plt.ylabel('Number of participants',
          fontsize = 12,
          fontweight = 'bold')
plt.savefig('visualizations/GENDER.png', dpi = 300)
plt.show()

# %%
plt.hist(x = data['Age'],
         bins = 7,
         histtype = 'bar',
         color = '#124E78')

plt.title('Age distribution in the survey',
          fontsize = 14,
          fontweight = 'bold')
plt.xlabel('Years',
           fontsize = 12,
           fontweight = 'bold')
plt.ylabel('Number of participants',
           fontsize = 12,
           fontweight = 'bold')
plt.savefig('visualizations/ADS.png', dpi = 300)
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (18,5))

ax1.scatter(data['Annual Income (k$)'], data['Spending Score (1-100)'],                               alpha = 0.5,
            color = '#FF3864')
ax1.set_title('Annual Income compared to Spending Score',
              fontsize = 12,
              fontweight = 'bold')
ax1.set_xlabel('Annual Income',
               fontsize = 8,
               fontweight = 'bold')
ax1.set_ylabel('Spending Score',
               fontsize = 8,
               fontweight = 'bold')

ax2.scatter(data['Age'], data['Annual Income (k$)'],
            alpha = 0.5,
            color = '#261447')
ax2.set_title('Annual Income compared to Age',
              fontsize = 12,
              fontweight = 'bold')
ax2.set_xlabel('Age',
               fontsize = 8,
               fontweight = 'bold')
ax2.set_ylabel('Annual Income',
               fontsize = 8,
               fontweight = 'bold')

ax3.scatter( data['Age'], data['Spending Score (1-100)'],
            alpha = 0.5,
            color = '#F39C6B')
ax3.set_title('Spending Score compared to Age',
              fontsize = 12,
              fontweight = 'bold')
ax3.set_xlabel('Age',
               fontsize = 8,
               fontweight = 'bold')
ax3.set_ylabel('Spending Score',
               fontsize = 8,
               fontweight = 'bold')
plt.savefig('visualizations/AISAIASSA.png', dpi = 300)
plt.show()

# %%
data[data['Genre'] == 1].count()
data[data['Genre'] == 0].count()
# Out:
# CustomerID                88
# Genre                     88
# Age                       88
# Annual Income (k$)        88
# Spending Score (1-100)    88
# dtype: int64

# %%
data.Genre[(data.Genre == 1)].count()
# Out:
# 112
